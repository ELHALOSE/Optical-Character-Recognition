# %% [markdown]
# # Optical character recognition (OCR)

# %%
# !pip install easyocr
# !pip install imutils

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import imutils
import easyocr

# %%
img = cv2.imread("image3.jpeg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray,cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray, 30, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
#contour
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contourss = imutils.grab_contours(keypoints)
contours = sorted(contourss, key=cv2.contourArea, reverse=True)[:10]
len(contours)
# Out:
# 10

# %%
# location
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break
len(location)
# Out:
# 4

# %%
location
# Out:
# array([[[526, 275]],
#
#        [[642, 275]],
#
#        [[644, 305]],
#
#        [[530, 305]]], dtype=int32)

# %%
#create window empty and draw Plate
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], -1,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
# coordinate rectangle
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = new_image[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[7, 0], [115, 0], [115, 31], [7, 31]], 'UK69 TVR', 0.6739907946872098)]

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, (approx[0][0]), (approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in e:\users\compumarts\anaconda3\lib\site-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in e:\users\compumarts\anaconda3\lib\site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: packaging>=21.3 in e:\users\compumarts\anaconda3\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in e:\users\compumarts\anaconda3\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.9)
